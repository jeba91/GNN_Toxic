# %%
"""
    IMPORTING LIBS
"""
import dgl

import numpy as np
import os
import socket
import time
import random
import glob
import argparse, json
import pandas as pd

from os import listdir
from os.path import isfile, join

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

from tensorboardX import SummaryWriter
from tqdm import tqdm

from sklearn.metrics import balanced_accuracy_score, confusion_matrix

import sklearn
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import math

# custom function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# some_file.py
import sys
#change location to GNN_RIVM folder
sys.path.insert(1, '/home/jeroen/Documents/Toxic/GNN_rivm/benchmark')

from nets.TUs_graph_classification.load_net import gnn_model # import GNNs
from data.data import LoadData # import dataset
from train.train_TUs_graph_classification import train_epoch, evaluate_network, evaluate_network2 # import train functions

drop_last = False
device = torch.device("cpu")

# %%
#function to convert net params file to needed feature vector for model loading
def create_net_params(file_name):
    f = open(file_name, "r")
    n_params = (f.readlines()[5].split(" "))
    net_params = dict()
    pbt_params_int = ['in_dim', 'hidden_dim', 'n_classes', 'L', 'n_mlp_GIN']
    int_idx = [29,3,31,1,9]
    pbt_params_str = ['learn_eps_GIN', 'neighbor_aggr_GIN', 'readout', 'graph_norm', 'batch_norm', 'residual']
    str_idx = [11,13,7,19,21,5]
    
    for idx1, par in enumerate(pbt_params_int):
        net_params[par] = int(n_params[int_idx[idx1]].split(',')[0])
    net_params['in_feat_dropout'] = float(n_params[15].split(',')[0])
    net_params['dropout'] = float(n_params[17].split(',')[0])
    for idx2, par in enumerate(pbt_params_str):
        net_params[par] =  n_params[str_idx[idx2]].split(',')[0].strip("'")
    return net_params

# %%
#load data and best representation
folder = "GINPBTn/"
model_str = "GIN"
gin_file = "GIN_PBT_Repn3_GPU0_08h22m01s_on_Jul_01_2020"
gin_np = create_net_params(folder+"config_"+gin_file+".txt")
#correct for error in config file
gin_np['L'] = 4
gin_np['hidden_dim'] = 128

# %%
#load both datasets
dataset_pZZS = LoadData("pZZS_Rep3")
dataset = LoadData("PBT_Repn3")
# Out:
# 129
# preparing 129 graphs for the ALL set...
# [!] Dataset:  pZZS_Rep3
# Time taken: 1.3272s
# 971
# preparing 971 graphs for the ALL set...
# [!] Dataset:  PBT_Repn3
# Time taken: 9.6463s

# %%
#print accuracy for test dataset of standard data
def test_model(net_params, model_name, dataset, model_str):
    accs = []
    for i in range(10):
        model = gnn_model(model_str, net_params)
        onlyfiles = [f for f in listdir(model_name + str(i)) if isfile(join(model_name + str(i), f))]
        model.load_state_dict(torch.load(model_name + str(i) +"/"+ onlyfiles[-1]))
        trainset, valset, testset = dataset.train[i], dataset.val[i], dataset.test[i]
#         train_loader = DataLoader(trainset, batch_size=20, shuffle=True, drop_last=drop_last, collate_fn=dataset.collate)
#         val_loader = DataLoader(valset, batch_size=20, shuffle=False, drop_last=drop_last, collate_fn=dataset.collate)
        test_loader = DataLoader(testset, batch_size=1, shuffle=False, drop_last=drop_last, collate_fn=dataset.collate)
        epoch_val_loss, epoch_val_acc = evaluate_network(model, device, test_loader, 999)
        accs.append(epoch_val_acc)
    print(np.mean(accs),np.std(accs))
#     print(accs)

# %%
#returns 10 scores for 10 models of cross validation
def test_model_s(net_params, model_name, dataset, model_str):
    accs = []
    labs = []
    for i in range(10):
        model = gnn_model(model_str, net_params)
        onlyfiles = [f for f in listdir(model_name + str(i)) if isfile(join(model_name + str(i), f))]
        model.load_state_dict(torch.load(model_name + str(i) +"/"+ onlyfiles[-1]))
        allset = dataset.all
        test_loader = DataLoader(allset, batch_size=1, shuffle=False, drop_last=drop_last, collate_fn=dataset.collate)
        epoch_val_loss, labels, score = evaluate_network2(model, device, test_loader, 999)
        accs.append(score)
    return accs

# %%
#get accuracy and scores on new dataset
test_model(gin_np, folder+gin_file+"/RUN_", dataset, model_str)
accs = test_model_s(gin_np, folder+gin_file+"/RUN_", dataset_pZZS, model_str)
# Out:
# 0.9521484682667992 0.032889738854116106

# %%
#create empty score vector
#add all scores as sum in the vector
#before adding, convert to sigmoid for normalized scores
#print mean of the scores, difference between scores and predicted label for pZZS dataset

score = np.zeros([len(accs[0]), 2])
for ac in accs:
    score += sigmoid(np.array(ac))
#Sort by highest score on 1
score = sorted(score, key=lambda tup: tup[1], reverse=True)
pred = np.argmax(score, axis=1)

for idx, pr in enumerate(pred):
    print("Predicted: %2d, Score 0: %.3f, Score 1: %.3f, diff: %.2f" %(pr, score[idx][0]/10, score[idx][1]/10, abs((score[idx][0]/10)-(score[idx][1]/10))))
# Out:
# Predicted:  1, Score 0: 0.993, Score 1: 1.000, diff: 0.01
# Predicted:  1, Score 0: 0.526, Score 1: 0.994, diff: 0.47
# Predicted:  1, Score 0: 0.885, Score 1: 0.992, diff: 0.11
# Predicted:  1, Score 0: 0.974, Score 1: 0.991, diff: 0.02
# Predicted:  1, Score 0: 0.646, Score 1: 0.986, diff: 0.34
# Predicted:  0, Score 0: 1.000, Score 1: 0.978, diff: 0.02
# Predicted:  0, Score 0: 0.997, Score 1: 0.966, diff: 0.03
# Predicted:  1, Score 0: 0.913, Score 1: 0.961, diff: 0.05
# Predicted:  0, Score 0: 0.993, Score 1: 0.901, diff: 0.09
# Predicted:  1, Score 0: 0.900, Score 1: 0.900, diff: 0.00
# Predicted:  1, Score 0: 0.891, Score 1: 0.899, diff: 0.01
# Predicted:  1, Score 0: 0.756, Score 1: 0.899, diff: 0.14
# Predicted:  1, Score 0: 0.803, Score 1: 0.899, diff: 0.10
# Predicted:  1, Score 0: 0.845, Score 1: 0.896, diff: 0.05
# Predicted:  1, Score 0: 0.704, Score 1: 0.892, diff: 0.19
# Predicted:  0, Score 0: 0.908, Score 1: 0.885, diff: 0.02
# Predicted:  0, Score 0: 0.947, Score 1: 0.880, diff: 0.07
# Predicted:  1, Score 0: 0.817, Score 1: 0.880, diff: 0.06
# Predicted:  1, Score 0: 0.799, Score 1: 0.878, diff: 0.08
# Predicted:  1, Score 0: 0.852, Score 1: 0.868, diff: 0.02
# Predicted:  0, Score 0: 0.888, Score 1: 0.867, diff: 0.02
# Predicted:  0, Score 0: 0.999, Score 1: 0.837, diff: 0.16
# Predicted:  0, Score 0: 0.849, Score 1: 0.834, diff: 0.01
# Predicted:  1, Score 0: 0.694, Score 1: 0.832, diff: 0.14
# Predicted:  1, Score 0: 0.797, Score 1: 0.830, diff: 0.03
# Predicted:  0, Score 0: 0.964, Score 1: 0.826, diff: 0.14
# Predicted:  0, Score 0: 0.960, Score 1: 0.824, diff: 0.14
# Predicted:  1, Score 0: 0.710, Score 1: 0.822, diff: 0.11
# Predicted:  1, Score 0: 0.516, Score 1: 0.820, diff: 0.30
# Predicted:  1, Score 0: 0.683, Score 1: 0.815, diff: 0.13
# Predicted:  1, Score 0: 0.683, Score 1: 0.815, diff: 0.13
# Predicted:  1, Score 0: 0.691, Score 1: 0.815, diff: 0.12
# Predicted:  1, Score 0: 0.747, Score 1: 0.814, diff: 0.07
# Predicted:  1, Score 0: 0.691, Score 1: 0.812, diff: 0.12
# Predicted:  0, Score 0: 0.853, Score 1: 0.807, diff: 0.05
# Predicted:  1, Score 0: 0.788, Score 1: 0.802, diff: 0.01
# Predicted:  1, Score 0: 0.788, Score 1: 0.802, diff: 0.01
# Predicted:  1, Score 0: 0.735, Score 1: 0.801, diff: 0.07
# Predicted:  1, Score 0: 0.510, Score 1: 0.800, diff: 0.29
# Predicted:  1, Score 0: 0.789, Score 1: 0.800, diff: 0.01
# Predicted:  1, Score 0: 0.751, Score 1: 0.798, diff: 0.05
# Predicted:  1, Score 0: 0.360, Score 1: 0.795, diff: 0.43
# Predicted:  0, Score 0: 0.900, Score 1: 0.768, diff: 0.13
# Predicted:  0, Score 0: 0.819, Score 1: 0.762, diff: 0.06
# Predicted:  1, Score 0: 0.399, Score 1: 0.756, diff: 0.36
# Predicted:  0, Score 0: 0.996, Score 1: 0.751, diff: 0.24
# Predicted:  1, Score 0: 0.678, Score 1: 0.747, diff: 0.07
# Predicted:  0, Score 0: 0.824, Score 1: 0.734, diff: 0.09
# Predicted:  0, Score 0: 0.768, Score 1: 0.733, diff: 0.04
# Predicted:  0, Score 0: 0.842, Score 1: 0.725, diff: 0.12
# Predicted:  0, Score 0: 0.727, Score 1: 0.722, diff: 0.01
# Predicted:  0, Score 0: 0.903, Score 1: 0.721, diff: 0.18
# Predicted:  1, Score 0: 0.697, Score 1: 0.709, diff: 0.01
# Predicted:  0, Score 0: 0.747, Score 1: 0.708, diff: 0.04
# Predicted:  0, Score 0: 0.920, Score 1: 0.701, diff: 0.22
# Predicted:  0, Score 0: 0.979, Score 1: 0.701, diff: 0.28
# Predicted:  0, Score 0: 0.751, Score 1: 0.696, diff: 0.06
# Predicted:  1, Score 0: 0.692, Score 1: 0.696, diff: 0.00
# Predicted:  0, Score 0: 0.947, Score 1: 0.686, diff: 0.26
# Predicted:  0, Score 0: 0.774, Score 1: 0.679, diff: 0.09
# Predicted:  0, Score 0: 0.884, Score 1: 0.671, diff: 0.21
# Predicted:  0, Score 0: 0.997, Score 1: 0.670, diff: 0.33
# Predicted:  0, Score 0: 0.879, Score 1: 0.666, diff: 0.21
# Predicted:  0, Score 0: 0.904, Score 1: 0.643, diff: 0.26
# Predicted:  0, Score 0: 0.722, Score 1: 0.642, diff: 0.08
# Predicted:  0, Score 0: 0.989, Score 1: 0.637, diff: 0.35
# Predicted:  0, Score 0: 0.780, Score 1: 0.627, diff: 0.15
# Predicted:  0, Score 0: 0.979, Score 1: 0.614, diff: 0.36
# Predicted:  0, Score 0: 0.869, Score 1: 0.614, diff: 0.25
# Predicted:  0, Score 0: 0.991, Score 1: 0.606, diff: 0.38
# Predicted:  0, Score 0: 0.595, Score 1: 0.581, diff: 0.01
# Predicted:  1, Score 0: 0.446, Score 1: 0.581, diff: 0.14
# Predicted:  0, Score 0: 0.812, Score 1: 0.579, diff: 0.23
# Predicted:  0, Score 0: 0.705, Score 1: 0.575, diff: 0.13
# Predicted:  0, Score 0: 0.819, Score 1: 0.573, diff: 0.25
# Predicted:  1, Score 0: 0.425, Score 1: 0.556, diff: 0.13
# Predicted:  0, Score 0: 0.977, Score 1: 0.539, diff: 0.44
# Predicted:  0, Score 0: 0.800, Score 1: 0.526, diff: 0.27
# Predicted:  1, Score 0: 0.417, Score 1: 0.521, diff: 0.10
# Predicted:  1, Score 0: 0.417, Score 1: 0.516, diff: 0.10
# Predicted:  0, Score 0: 0.749, Score 1: 0.515, diff: 0.23
# Predicted:  0, Score 0: 0.744, Score 1: 0.511, diff: 0.23
# Predicted:  0, Score 0: 0.807, Score 1: 0.499, diff: 0.31
# Predicted:  0, Score 0: 0.702, Score 1: 0.494, diff: 0.21
# Predicted:  0, Score 0: 0.620, Score 1: 0.494, diff: 0.13
# Predicted:  1, Score 0: 0.150, Score 1: 0.485, diff: 0.33
# Predicted:  1, Score 0: 0.431, Score 1: 0.476, diff: 0.04
# Predicted:  0, Score 0: 0.700, Score 1: 0.475, diff: 0.22
# Predicted:  0, Score 0: 0.853, Score 1: 0.470, diff: 0.38
# Predicted:  0, Score 0: 0.986, Score 1: 0.465, diff: 0.52
# Predicted:  0, Score 0: 0.690, Score 1: 0.459, diff: 0.23
# Predicted:  0, Score 0: 0.690, Score 1: 0.459, diff: 0.23
# Predicted:  0, Score 0: 0.996, Score 1: 0.448, diff: 0.55
# Predicted:  0, Score 0: 0.997, Score 1: 0.447, diff: 0.55
# Predicted:  0, Score 0: 0.787, Score 1: 0.445, diff: 0.34
# Predicted:  0, Score 0: 0.593, Score 1: 0.438, diff: 0.16
# Predicted:  0, Score 0: 0.755, Score 1: 0.429, diff: 0.33
# Predicted:  0, Score 0: 0.987, Score 1: 0.412, diff: 0.57
# Predicted:  0, Score 0: 0.748, Score 1: 0.400, diff: 0.35
# Predicted:  0, Score 0: 0.990, Score 1: 0.397, diff: 0.59
# Predicted:  0, Score 0: 0.496, Score 1: 0.396, diff: 0.10
# Predicted:  0, Score 0: 0.867, Score 1: 0.374, diff: 0.49
# Predicted:  0, Score 0: 0.983, Score 1: 0.372, diff: 0.61
# Predicted:  0, Score 0: 0.926, Score 1: 0.367, diff: 0.56
# Predicted:  0, Score 0: 0.662, Score 1: 0.337, diff: 0.33
# Predicted:  0, Score 0: 0.778, Score 1: 0.324, diff: 0.45
# Predicted:  0, Score 0: 0.908, Score 1: 0.318, diff: 0.59
# Predicted:  0, Score 0: 0.900, Score 1: 0.298, diff: 0.60
# Predicted:  0, Score 0: 0.807, Score 1: 0.293, diff: 0.51
# Predicted:  0, Score 0: 0.774, Score 1: 0.282, diff: 0.49
# Predicted:  0, Score 0: 0.802, Score 1: 0.230, diff: 0.57
# Predicted:  0, Score 0: 0.783, Score 1: 0.225, diff: 0.56
# Predicted:  0, Score 0: 0.235, Score 1: 0.216, diff: 0.02
# Predicted:  0, Score 0: 0.980, Score 1: 0.213, diff: 0.77
# Predicted:  0, Score 0: 0.987, Score 1: 0.207, diff: 0.78
# Predicted:  0, Score 0: 0.726, Score 1: 0.207, diff: 0.52
# Predicted:  0, Score 0: 0.798, Score 1: 0.200, diff: 0.60
# Predicted:  0, Score 0: 0.611, Score 1: 0.200, diff: 0.41
# Predicted:  0, Score 0: 0.559, Score 1: 0.197, diff: 0.36
# Predicted:  0, Score 0: 0.804, Score 1: 0.193, diff: 0.61
# Predicted:  0, Score 0: 0.629, Score 1: 0.181, diff: 0.45
# Predicted:  0, Score 0: 0.730, Score 1: 0.153, diff: 0.58
# Predicted:  0, Score 0: 0.547, Score 1: 0.145, diff: 0.40
# Predicted:  0, Score 0: 0.643, Score 1: 0.139, diff: 0.50
# Predicted:  0, Score 0: 0.838, Score 1: 0.102, diff: 0.74
# Predicted:  0, Score 0: 0.400, Score 1: 0.100, diff: 0.30
# Predicted:  0, Score 0: 0.400, Score 1: 0.100, diff: 0.30
# Predicted:  0, Score 0: 0.477, Score 1: 0.100, diff: 0.38
# Predicted:  0, Score 0: 0.628, Score 1: 0.098, diff: 0.53
