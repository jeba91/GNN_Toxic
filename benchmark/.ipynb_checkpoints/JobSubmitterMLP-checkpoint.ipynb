# %%
# -*- coding: utf-8 -*-
import argparse 
import itertools
import datetime
import os
import json
import time
import subprocess

# %%
def stringify_config(configuration, first, last):
    out = ""
    for i in range(first, last + 1):
        out = out + str(configuration[i]) + " "
        
    return out

def get_num_running_jobs():
    cmd = "bjobs -q bio-gpu"
    returned_value = subprocess.run(cmd, capture_output=True, shell=True) 
    output = returned_value.stdout.decode()
    
    number_of_jobs = 0
    if len(output) > 0: 
    	number_of_jobs = len(output.split("\n")) - 2
    
    return number_of_jobs

# %%
now = datetime.datetime.now().strftime("%y%m%d_%H%M")
output_path = './configs/test/' 
if not os.path.exists(output_path):
    os.makedirs(output_path)

### GPU settings
use = [True]
id_gpu = [0]
    
### Test settings 
model = ["MLP"]
dataset = ["TOX"]
out_dir = ["out/TOX_graph_classification/"]

### Parameter settings 
seed = [79]
epochs = [1000]
batch_size = [20]
init_lr = [1e-3]
lr_reduce_factor = [0.5]
lr_schedule_patience = [25]
min_lr = [1e-10]
weight_decay = [0.0]
print_epoch_interval = [5]
max_time = [48]

### net parameters settings
L = [2,4,6,8,10,12]
hidden_dim = [25,50,150,200]
out_dim = [128]
readout = ["mean"]
gated = [False]
in_feat_dropout = [0.5]
dropout = [0.5]


gpu_combis = list(itertools.product(use, id_gpu))


param_combis = list(itertools.product(seed,epochs,batch_size,init_lr,
                                      lr_reduce_factor,lr_schedule_patience,
                                      min_lr, weight_decay, print_epoch_interval, max_time))
                    
net_combis = list(itertools.product(L, hidden_dim, out_dim, readout, gated, in_feat_dropout, dropout))

combis = list(itertools.product(gpu_combis, model, dataset, out_dir, param_combis, net_combis))

# %%
headers = ["gpu", "model", "dataset", "out_dir", "params", "net_params"]

parameters = ["seed","epochs","batch_size","init_lr","lr_reduce_factor",
              "lr_schedule_patience","min_lr", "weight_decay", "print_epoch_interval", "max_time"]

net = ["L", "hidden_dim", "out_dim", "readout", "gated", "in_feat_dropout", "dropout"]

gpu = ["use", "id"]

# %%
def create_dict(comb_list, name_list):
    dct = {}
    for i in range(len(comb_list)):
        dct[name_list[i]] = comb_list[i]
    return dct

# %%
for i in range(len(combis)):
    combis[i] = create_dict(combis[i], headers)
    combis[i]["gpu"] = create_dict(combis[i]["gpu"], gpu)
    combis[i]["params"] = create_dict(combis[i]["params"], parameters)
    combis[i]["net_params"] = create_dict(combis[i]["net_params"], net)
    save_name = 'TOX' + combis[i]['model'] + str(i) +'.json'
    with open(output_path + save_name, 'w') as fp:
        json.dump(combis[i], fp, sort_keys=False, indent=4, separators=(',', ': '))

# %%
print(len(combis))
# Out:
# 24

# %%
# For loop creating jobs
dataset = "R_Rep"
# python $code --dataset $dataset --config 'configs/test/TOXGIN0.json'
nt = datetime.datetime.now().strftime("%d%m-%H%M")

for i, configuration in enumerate(combis):
    for j in [1,2,3,4]:
        command = "bsub -q bio-gpu "
        pyth = " python main_TUs_graph_classification.py --dataset "
        conf = " --config "
        save_name = 'TOX' + configuration['model'] + str(i) +'.json'
        out_name = 'TOX' + configuration['model'] + str(i) + dataset + str(j) + "_" + str(nt) + ".txt"
        out = "-o bio_grid/" + out_name
        error = " -e bio_grid/" + out_name
        job =  command + out + error + pyth + dataset + str(j) + conf + output_path + save_name

        
        # Wait until the job can be added to the queue
#         while get_num_running_jobs() >= max_running_jobs:
#             time.sleep(60)
        
        print(job)
#         os.system(job)
#         time.sleep(0.5)
# Out:
# bsub -q bio-gpu -o bio_grid/TOXMLP0R_Rep1_0407-1225.txt -e bio_grid/TOXMLP0R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP0.json
# bsub -q bio-gpu -o bio_grid/TOXMLP0R_Rep2_0407-1225.txt -e bio_grid/TOXMLP0R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP0.json
# bsub -q bio-gpu -o bio_grid/TOXMLP0R_Rep3_0407-1225.txt -e bio_grid/TOXMLP0R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP0.json
# bsub -q bio-gpu -o bio_grid/TOXMLP0R_Rep4_0407-1225.txt -e bio_grid/TOXMLP0R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP0.json
# bsub -q bio-gpu -o bio_grid/TOXMLP1R_Rep1_0407-1225.txt -e bio_grid/TOXMLP1R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP1.json
# bsub -q bio-gpu -o bio_grid/TOXMLP1R_Rep2_0407-1225.txt -e bio_grid/TOXMLP1R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP1.json
# bsub -q bio-gpu -o bio_grid/TOXMLP1R_Rep3_0407-1225.txt -e bio_grid/TOXMLP1R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP1.json
# bsub -q bio-gpu -o bio_grid/TOXMLP1R_Rep4_0407-1225.txt -e bio_grid/TOXMLP1R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP1.json
# bsub -q bio-gpu -o bio_grid/TOXMLP2R_Rep1_0407-1225.txt -e bio_grid/TOXMLP2R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP2.json
# bsub -q bio-gpu -o bio_grid/TOXMLP2R_Rep2_0407-1225.txt -e bio_grid/TOXMLP2R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP2.json
# bsub -q bio-gpu -o bio_grid/TOXMLP2R_Rep3_0407-1225.txt -e bio_grid/TOXMLP2R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP2.json
# bsub -q bio-gpu -o bio_grid/TOXMLP2R_Rep4_0407-1225.txt -e bio_grid/TOXMLP2R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP2.json
# bsub -q bio-gpu -o bio_grid/TOXMLP3R_Rep1_0407-1225.txt -e bio_grid/TOXMLP3R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP3.json
# bsub -q bio-gpu -o bio_grid/TOXMLP3R_Rep2_0407-1225.txt -e bio_grid/TOXMLP3R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP3.json
# bsub -q bio-gpu -o bio_grid/TOXMLP3R_Rep3_0407-1225.txt -e bio_grid/TOXMLP3R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP3.json
# bsub -q bio-gpu -o bio_grid/TOXMLP3R_Rep4_0407-1225.txt -e bio_grid/TOXMLP3R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP3.json
# bsub -q bio-gpu -o bio_grid/TOXMLP4R_Rep1_0407-1225.txt -e bio_grid/TOXMLP4R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP4.json
# bsub -q bio-gpu -o bio_grid/TOXMLP4R_Rep2_0407-1225.txt -e bio_grid/TOXMLP4R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP4.json
# bsub -q bio-gpu -o bio_grid/TOXMLP4R_Rep3_0407-1225.txt -e bio_grid/TOXMLP4R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP4.json
# bsub -q bio-gpu -o bio_grid/TOXMLP4R_Rep4_0407-1225.txt -e bio_grid/TOXMLP4R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP4.json
# bsub -q bio-gpu -o bio_grid/TOXMLP5R_Rep1_0407-1225.txt -e bio_grid/TOXMLP5R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP5.json
# bsub -q bio-gpu -o bio_grid/TOXMLP5R_Rep2_0407-1225.txt -e bio_grid/TOXMLP5R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP5.json
# bsub -q bio-gpu -o bio_grid/TOXMLP5R_Rep3_0407-1225.txt -e bio_grid/TOXMLP5R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP5.json
# bsub -q bio-gpu -o bio_grid/TOXMLP5R_Rep4_0407-1225.txt -e bio_grid/TOXMLP5R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP5.json
# bsub -q bio-gpu -o bio_grid/TOXMLP6R_Rep1_0407-1225.txt -e bio_grid/TOXMLP6R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP6.json
# bsub -q bio-gpu -o bio_grid/TOXMLP6R_Rep2_0407-1225.txt -e bio_grid/TOXMLP6R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP6.json
# bsub -q bio-gpu -o bio_grid/TOXMLP6R_Rep3_0407-1225.txt -e bio_grid/TOXMLP6R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP6.json
# bsub -q bio-gpu -o bio_grid/TOXMLP6R_Rep4_0407-1225.txt -e bio_grid/TOXMLP6R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP6.json
# bsub -q bio-gpu -o bio_grid/TOXMLP7R_Rep1_0407-1225.txt -e bio_grid/TOXMLP7R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP7.json
# bsub -q bio-gpu -o bio_grid/TOXMLP7R_Rep2_0407-1225.txt -e bio_grid/TOXMLP7R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP7.json
# bsub -q bio-gpu -o bio_grid/TOXMLP7R_Rep3_0407-1225.txt -e bio_grid/TOXMLP7R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP7.json
# bsub -q bio-gpu -o bio_grid/TOXMLP7R_Rep4_0407-1225.txt -e bio_grid/TOXMLP7R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP7.json
# bsub -q bio-gpu -o bio_grid/TOXMLP8R_Rep1_0407-1225.txt -e bio_grid/TOXMLP8R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP8.json
# bsub -q bio-gpu -o bio_grid/TOXMLP8R_Rep2_0407-1225.txt -e bio_grid/TOXMLP8R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP8.json
# bsub -q bio-gpu -o bio_grid/TOXMLP8R_Rep3_0407-1225.txt -e bio_grid/TOXMLP8R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP8.json
# bsub -q bio-gpu -o bio_grid/TOXMLP8R_Rep4_0407-1225.txt -e bio_grid/TOXMLP8R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP8.json
# bsub -q bio-gpu -o bio_grid/TOXMLP9R_Rep1_0407-1225.txt -e bio_grid/TOXMLP9R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP9.json
# bsub -q bio-gpu -o bio_grid/TOXMLP9R_Rep2_0407-1225.txt -e bio_grid/TOXMLP9R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP9.json
# bsub -q bio-gpu -o bio_grid/TOXMLP9R_Rep3_0407-1225.txt -e bio_grid/TOXMLP9R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP9.json
# bsub -q bio-gpu -o bio_grid/TOXMLP9R_Rep4_0407-1225.txt -e bio_grid/TOXMLP9R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP9.json
# bsub -q bio-gpu -o bio_grid/TOXMLP10R_Rep1_0407-1225.txt -e bio_grid/TOXMLP10R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP10.json
# bsub -q bio-gpu -o bio_grid/TOXMLP10R_Rep2_0407-1225.txt -e bio_grid/TOXMLP10R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP10.json
# bsub -q bio-gpu -o bio_grid/TOXMLP10R_Rep3_0407-1225.txt -e bio_grid/TOXMLP10R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP10.json
# bsub -q bio-gpu -o bio_grid/TOXMLP10R_Rep4_0407-1225.txt -e bio_grid/TOXMLP10R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP10.json
# bsub -q bio-gpu -o bio_grid/TOXMLP11R_Rep1_0407-1225.txt -e bio_grid/TOXMLP11R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP11.json
# bsub -q bio-gpu -o bio_grid/TOXMLP11R_Rep2_0407-1225.txt -e bio_grid/TOXMLP11R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP11.json
# bsub -q bio-gpu -o bio_grid/TOXMLP11R_Rep3_0407-1225.txt -e bio_grid/TOXMLP11R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP11.json
# bsub -q bio-gpu -o bio_grid/TOXMLP11R_Rep4_0407-1225.txt -e bio_grid/TOXMLP11R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP11.json
# bsub -q bio-gpu -o bio_grid/TOXMLP12R_Rep1_0407-1225.txt -e bio_grid/TOXMLP12R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP12.json
# bsub -q bio-gpu -o bio_grid/TOXMLP12R_Rep2_0407-1225.txt -e bio_grid/TOXMLP12R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP12.json
# bsub -q bio-gpu -o bio_grid/TOXMLP12R_Rep3_0407-1225.txt -e bio_grid/TOXMLP12R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP12.json
# bsub -q bio-gpu -o bio_grid/TOXMLP12R_Rep4_0407-1225.txt -e bio_grid/TOXMLP12R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP12.json
# bsub -q bio-gpu -o bio_grid/TOXMLP13R_Rep1_0407-1225.txt -e bio_grid/TOXMLP13R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP13.json
# bsub -q bio-gpu -o bio_grid/TOXMLP13R_Rep2_0407-1225.txt -e bio_grid/TOXMLP13R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP13.json
# bsub -q bio-gpu -o bio_grid/TOXMLP13R_Rep3_0407-1225.txt -e bio_grid/TOXMLP13R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP13.json
# bsub -q bio-gpu -o bio_grid/TOXMLP13R_Rep4_0407-1225.txt -e bio_grid/TOXMLP13R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP13.json
# bsub -q bio-gpu -o bio_grid/TOXMLP14R_Rep1_0407-1225.txt -e bio_grid/TOXMLP14R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP14.json
# bsub -q bio-gpu -o bio_grid/TOXMLP14R_Rep2_0407-1225.txt -e bio_grid/TOXMLP14R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP14.json
# bsub -q bio-gpu -o bio_grid/TOXMLP14R_Rep3_0407-1225.txt -e bio_grid/TOXMLP14R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP14.json
# bsub -q bio-gpu -o bio_grid/TOXMLP14R_Rep4_0407-1225.txt -e bio_grid/TOXMLP14R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP14.json
# bsub -q bio-gpu -o bio_grid/TOXMLP15R_Rep1_0407-1225.txt -e bio_grid/TOXMLP15R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP15.json
# bsub -q bio-gpu -o bio_grid/TOXMLP15R_Rep2_0407-1225.txt -e bio_grid/TOXMLP15R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP15.json
# bsub -q bio-gpu -o bio_grid/TOXMLP15R_Rep3_0407-1225.txt -e bio_grid/TOXMLP15R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP15.json
# bsub -q bio-gpu -o bio_grid/TOXMLP15R_Rep4_0407-1225.txt -e bio_grid/TOXMLP15R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP15.json
# bsub -q bio-gpu -o bio_grid/TOXMLP16R_Rep1_0407-1225.txt -e bio_grid/TOXMLP16R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP16.json
# bsub -q bio-gpu -o bio_grid/TOXMLP16R_Rep2_0407-1225.txt -e bio_grid/TOXMLP16R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP16.json
# bsub -q bio-gpu -o bio_grid/TOXMLP16R_Rep3_0407-1225.txt -e bio_grid/TOXMLP16R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP16.json
# bsub -q bio-gpu -o bio_grid/TOXMLP16R_Rep4_0407-1225.txt -e bio_grid/TOXMLP16R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP16.json
# bsub -q bio-gpu -o bio_grid/TOXMLP17R_Rep1_0407-1225.txt -e bio_grid/TOXMLP17R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP17.json
# bsub -q bio-gpu -o bio_grid/TOXMLP17R_Rep2_0407-1225.txt -e bio_grid/TOXMLP17R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP17.json
# bsub -q bio-gpu -o bio_grid/TOXMLP17R_Rep3_0407-1225.txt -e bio_grid/TOXMLP17R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP17.json
# bsub -q bio-gpu -o bio_grid/TOXMLP17R_Rep4_0407-1225.txt -e bio_grid/TOXMLP17R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP17.json
# bsub -q bio-gpu -o bio_grid/TOXMLP18R_Rep1_0407-1225.txt -e bio_grid/TOXMLP18R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP18.json
# bsub -q bio-gpu -o bio_grid/TOXMLP18R_Rep2_0407-1225.txt -e bio_grid/TOXMLP18R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP18.json
# bsub -q bio-gpu -o bio_grid/TOXMLP18R_Rep3_0407-1225.txt -e bio_grid/TOXMLP18R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP18.json
# bsub -q bio-gpu -o bio_grid/TOXMLP18R_Rep4_0407-1225.txt -e bio_grid/TOXMLP18R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP18.json
# bsub -q bio-gpu -o bio_grid/TOXMLP19R_Rep1_0407-1225.txt -e bio_grid/TOXMLP19R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP19.json
# bsub -q bio-gpu -o bio_grid/TOXMLP19R_Rep2_0407-1225.txt -e bio_grid/TOXMLP19R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP19.json
# bsub -q bio-gpu -o bio_grid/TOXMLP19R_Rep3_0407-1225.txt -e bio_grid/TOXMLP19R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP19.json
# bsub -q bio-gpu -o bio_grid/TOXMLP19R_Rep4_0407-1225.txt -e bio_grid/TOXMLP19R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP19.json
# bsub -q bio-gpu -o bio_grid/TOXMLP20R_Rep1_0407-1225.txt -e bio_grid/TOXMLP20R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP20.json
# bsub -q bio-gpu -o bio_grid/TOXMLP20R_Rep2_0407-1225.txt -e bio_grid/TOXMLP20R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP20.json
# bsub -q bio-gpu -o bio_grid/TOXMLP20R_Rep3_0407-1225.txt -e bio_grid/TOXMLP20R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP20.json
# bsub -q bio-gpu -o bio_grid/TOXMLP20R_Rep4_0407-1225.txt -e bio_grid/TOXMLP20R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP20.json
# bsub -q bio-gpu -o bio_grid/TOXMLP21R_Rep1_0407-1225.txt -e bio_grid/TOXMLP21R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP21.json
# bsub -q bio-gpu -o bio_grid/TOXMLP21R_Rep2_0407-1225.txt -e bio_grid/TOXMLP21R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP21.json
# bsub -q bio-gpu -o bio_grid/TOXMLP21R_Rep3_0407-1225.txt -e bio_grid/TOXMLP21R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP21.json
# bsub -q bio-gpu -o bio_grid/TOXMLP21R_Rep4_0407-1225.txt -e bio_grid/TOXMLP21R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP21.json
# bsub -q bio-gpu -o bio_grid/TOXMLP22R_Rep1_0407-1225.txt -e bio_grid/TOXMLP22R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP22.json
# bsub -q bio-gpu -o bio_grid/TOXMLP22R_Rep2_0407-1225.txt -e bio_grid/TOXMLP22R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP22.json
# bsub -q bio-gpu -o bio_grid/TOXMLP22R_Rep3_0407-1225.txt -e bio_grid/TOXMLP22R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP22.json
# bsub -q bio-gpu -o bio_grid/TOXMLP22R_Rep4_0407-1225.txt -e bio_grid/TOXMLP22R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP22.json
# bsub -q bio-gpu -o bio_grid/TOXMLP23R_Rep1_0407-1225.txt -e bio_grid/TOXMLP23R_Rep1_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep1 --config ./configs/test/TOXMLP23.json
# bsub -q bio-gpu -o bio_grid/TOXMLP23R_Rep2_0407-1225.txt -e bio_grid/TOXMLP23R_Rep2_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep2 --config ./configs/test/TOXMLP23.json
# bsub -q bio-gpu -o bio_grid/TOXMLP23R_Rep3_0407-1225.txt -e bio_grid/TOXMLP23R_Rep3_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep3 --config ./configs/test/TOXMLP23.json
# bsub -q bio-gpu -o bio_grid/TOXMLP23R_Rep4_0407-1225.txt -e bio_grid/TOXMLP23R_Rep4_0407-1225.txt python main_TUs_graph_classification.py --dataset R_Rep4 --config ./configs/test/TOXMLP23.json
